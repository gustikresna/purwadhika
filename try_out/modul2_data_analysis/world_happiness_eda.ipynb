# %% [markdown]
# # SOAL TRY OUT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t

# %%
df = pd.read_csv('2019.csv')
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
######## NOMOR 1 #########

# %%
#GENEROSITY

# %%
#central tendency
print('Generosity mean :', df.Generosity.mean())
print('Generosity median :', df.Generosity.median())
print('Generosity mode :', df.Generosity.mode()[0])
# Out:
# Generosity mean : 0.18484615384615383
# Generosity median : 0.1775
# Generosity mode : 0.153

# %%
#dispersion
print('Generosity Range:', df.Generosity.max()-df.Generosity.min())
print('')
print('Generosity Std:', df.Generosity.std())
print('')
print('Generosity Quartile:\n'+str(df.Generosity.quantile([0.25,0.5,0.75,1])))
print('')
print('Generosity IQR:', df.Generosity.quantile(0.75)-df.Generosity.quantile(0.25))
# Out:
# Generosity Range: 0.566
#
# Generosity Std: 0.09525444050922018
#
# Generosity Quartile:
# 0.25    0.10875
# 0.50    0.17750
# 0.75    0.24825
# 1.00    0.56600
# Name: Generosity, dtype: float64
#
# Generosity IQR: 0.1395

# %%
#distribution
(df.Generosity)
plt.title('Generosity')
plt.xlabel('Generosity index')
plt.ylabel('Frequency')


plt.axvline(df.Generosity.mean(), color = 'red', linestyle='--')
plt.axvline(df.Generosity.median(), color = 'blue', linestyle='--')
plt.axvline(df.Generosity.mode()[0], color = 'black', linestyle='--')

plt.show()

# %%
#PERCEPTIONS OF CORRUPTION

# %%
#central tendency
print('Perceptions of corruption mean :', df['Perceptions of corruption'].mean())
print('Perceptions of corruption median :', df['Perceptions of corruption'].median())
print('Perceptions of corruption mode :', df['Perceptions of corruption'].mode()[0])
# Out:
# Perceptions of corruption mean : 0.11060256410256411
# Perceptions of corruption median : 0.08549999999999999
# Perceptions of corruption mode : 0.028

# %%
#dispersion
print('Generosity Range:', df['Perceptions of corruption'].max()-world_happiness_2019['Perceptions of corruption'].min())
print('')
print('Generosity Std:', df['Perceptions of corruption'].std())
print('')
print('Generosity Quartile:\n'+str(df['Perceptions of corruption'].quantile([0.25,0.5,0.75,1])))
print('')
print('Generosity IQR:', df['Perceptions of corruption'].quantile(0.75)-df['Perceptions of corruption'].quantile(0.25))
# Out:
# Generosity Range: 0.453
#
# Generosity Std: 0.09453783536745279
#
# Generosity Quartile:
# 0.25    0.04700
# 0.50    0.08550
# 0.75    0.14125
# 1.00    0.45300
# Name: Perceptions of corruption, dtype: float64
#
# Generosity IQR: 0.09424999999999999

# %%
#distribution
pl.hist(df['Perceptions of corruption'])
plt.title('Perceptions of corruption')
plt.xlabel('Perceptions of corruption index')
plt.ylabel('Frequency')


plt.axvline(df['Perceptions of corruption'].mean(), color = 'red', linestyle='--')
plt.axvline(df['Perceptions of corruption'].median(), color = 'blue', linestyle='--')
plt.axvline(df['Perceptions of corruption'].mode()[0], color = 'black', linestyle='--')

plt.show()

# %%
######## NOMOR 2 #########

# %%
#finding outlier on social support
plt.boxplot('Index', df['Social support'], vert=False)
plt.title('Social Support Index')
plt.xlabel('Social Support')
plt.ylabel('Index')
plt.show()

# %%
q3 = df['Social support'].quantile(0.75)
q1 = df['Social support'].quantile(0.25)
iqr = q3 - q1
outlier_social_supp = df[['Country or region', 'Social support']][(df['Social support']< q1 - 1.5*iqr) | (df['Social support']>q3+1.5*iqr)]
outlier_social_supp
# Out:
#             Country or region  Social support
# 101                     Benin           0.437
# 144                   Burundi           0.447
# 148                     Syria           0.378
# 154  Central African Republic           0.000

# %%
######## NOMOR 3 #########

# %%
#Distribution of freedom to make life choices
plt.hist('Freedom to make life choices', data=df, bins=10)
plt.title('Freedom to make life choices')
plt.xlabel('Index')
plt.ylabel('Frequency')

plt.axvline(df['Freedom to make life choices'].mean(), color = 'red', linestyle='--')
plt.axvline(df['Freedom to make life choices'].median(), color = 'blue', linestyle='--')
plt.axvline(df['Freedom to make life choices'].mode()[0], color = 'black', linestyle='--')
plt.show()

# %%
#left skewed

# %%
######## NOMOR 4 #########

# %%
#korelasi
gdp = df['GDP per capita']
soc_supp = df['Social support']
health_lifexp = df['Healthy life expectancy']
score = df['Score']

# %%
fig,ax = plt.subplots(1,3, figsize=(9,3), sharey=True)
ax[0].scatter(score,gdp)
ax[0].set_title('Score vs GDP')
ax[0].set_ylabel('Index')
ax[1].scatter(score, soc_supp)
ax[1].set_title('Score vs Social Support')
ax[2].scatter(score, health_lifexp)
ax[2].set_title('Score vs Health Life Expectancy')
plt.show()

# %%
#SINCE LINEAR USE PEARSON CORRELATION

# %%
np.corrcoef(score, gdp)
# Out:
# array([[1.        , 0.79388287],
#        [0.79388287, 1.        ]])

# %%
np.corrcoef(score, soc_supp)
# Out:
# array([[1.        , 0.77705779],
#        [0.77705779, 1.        ]])

# %%
np.corrcoef(score, health_lifexp)
# Out:
# array([[1.        , 0.77988315],
#        [0.77988315, 1.        ]])

# %%
#GDP has the highest correlation with Score
#Since GDP has high impact to Happiness, Government should focus on increasing GDP per capita of their country.

# %%
######## NOMOR 5 #########

# %%
#Country with score above average
country_highscore = df[df.Score > df.Score.mean()]
len(country_highscore['Country or region'])
# Out:
# 77

# %%
#GDP per capita
gdp_sorted = country_highscore.sort_values(by='GDP per capita', ascending=False).iloc[0:5]
plt.bar(gdp_sorted['Country or region'], gdp_sorted['GDP per capita'])
plt.title('Top 5 GDP per Capita')
plt.ylabel('GDP per Capita')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.show()

# %%
#Perceptions of Corruption
corruption_sorted = country_highscore.sort_values(by='Perceptions of corruption').iloc[0:5]
plt.bar(corruption_sorted['Country or region'], corruption_sorted['Perceptions of corruption'])
plt.title('Lowest 5 Perceptions of Corruption')
plt.ylabel('Perceptions of Corruption')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.show()

# %%
#Generosity
generosity_sorted = country_highscore.sort_values(by='Generosity').iloc[0:5]
plt.bar(generosity_sorted['Country or region'], generosity_sorted['Generosity'])
plt.title('Lowest 5 Generosity')
plt.ylabel('Generosity')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.show()
